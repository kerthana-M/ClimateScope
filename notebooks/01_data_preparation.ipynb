# %%
import pandas as pd
import numpy as np

# %%
data_path = "C:\\Users\\keert\\OneDrive\\Desktop\\ClimateScope\\data\\raw\\GlobalWeatherRepository.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#    timezone      country     location_name  latitude  longitude  \
# 0       NaN  Afghanistan             Kabul     34.52      69.18
# 1       NaN      Albania            Tirana     41.33      19.82
# 2       NaN      Algeria           Algiers     36.76       3.05
# 3       NaN      Andorra  Andorra La Vella     42.50       1.52
# 4       NaN       Angola            Luanda     -8.84      13.23
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  2024-05-16 13:15                 26.6
# 1          1715849100  2024-05-16 10:45                 19.0
# 2          1715849100  2024-05-16 09:45                 23.0
# 3          1715849100  2024-05-16 10:45                  6.3
# 4          1715849100  2024-05-16 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# 1                    66.2  Partly cloudy  ...                1.1
# 2                    73.4          Sunny  ...               10.4
# 3                    43.3  Light drizzle  ...                0.7
# 4                    78.8  Partly cloudy  ...              183.4
#
#    air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0              26.6                         1                          1
# 1               2.0                         1                          1
# 2              18.4                         1                          1
# 3               0.9                         1                          1
# 4             262.3                         5                         10
#
#     sunrise    sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  04:50 AM  06:50 PM  12:12 PM  01:11 AM  Waxing Gibbous                 55
# 1  05:21 AM  07:54 PM  12:58 PM  02:14 AM  Waxing Gibbous                 55
# 2  05:40 AM  07:50 PM  01:15 PM  02:14 AM  Waxing Gibbous                 55
# 3  06:31 AM  09:11 PM  02:12 PM  03:31 AM  Waxing Gibbous                 55
# 4  06:12 AM  05:55 PM  01:17 PM  12:38 AM  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %%
print("Dataset shape:", df.shape)
print("\nColumns:")
print(df.columns)
df.info()
# Out:
# Dataset shape: (125501, 42)
#
# Columns:
# Index(['timezone', 'country', 'location_name', 'latitude', 'longitude',
#        'last_updated_epoch', 'temperature_celsius', 'temperature_fahrenheit',
#        'condition_text', 'wind_mph', 'wind_kph', 'wind_degree',
#        'wind_direction', 'pressure_mb', 'pressure_in', 'precip_mm',
#        'precip_in', 'humidity', 'cloud', 'feels_like_celsius',
#        'feels_like_fahrenheit', 'visibility_km', 'visibility_miles',
#        'uv_index', 'gust_mph', 'gust_kph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index', 'sunrise',
#        'sunset', 'moonrise', 'moonset', 'moon_phase', 'moon_illumination',
#        'year', 'month'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 125501 entries, 2024-05-16 13:15:00 to 2026-02-21 08:45:00
# Data columns (total 42 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   timezone                      0 non-null       float64
#  1   country                       125501 non-null  object
#  2   location_name                 125501 non-null  object
#  3   latitude                      125501 non-null  float64
#  4   longitude                     125501 non-null  float64
#  5   last_updated_epoch            125501 non-null  int64
#  6   temperature_celsius           125501 non-null  float64
#  7   temperature_fahrenheit        125501 non-null  float64
#  8   condition_text                125501 non-null  object
#  9   wind_mph                      125501 non-null  float64
#  10  wind_kph                      125501 non-null  float64
#  11  wind_degree                   125501 non-null  int64
#  12  wind_direction                125501 non-null  object
#  13  pressure_mb                   125501 non-null  float64
#  14  pressure_in                   125501 non-null  float64
#  15  precip_mm                     125501 non-null  float64
#  16  precip_in                     125501 non-null  float64
#  17  humidity                      125501 non-null  int64
#  18  cloud                         125501 non-null  int64
#  19  feels_like_celsius            125501 non-null  float64
#  20  feels_like_fahrenheit         125501 non-null  float64
#  21  visibility_km                 125501 non-null  float64
#  22  visibility_miles              125501 non-null  float64
#  23  uv_index                      125501 non-null  float64
#  24  gust_mph                      125501 non-null  float64
#  25  gust_kph                      125501 non-null  float64
#  26  air_quality_Carbon_Monoxide   125501 non-null  float64
#  27  air_quality_Ozone             125501 non-null  float64
#  28  air_quality_Nitrogen_dioxide  125501 non-null  float64
#  29  air_quality_Sulphur_dioxide   125501 non-null  float64
#  30  air_quality_PM2.5             125501 non-null  float64
#  31  air_quality_PM10              125501 non-null  float64
#  32  air_quality_us-epa-index      125501 non-null  int64
#  33  air_quality_gb-defra-index    125501 non-null  int64
#  34  sunrise                       125501 non-null  object
#  35  sunset                        125501 non-null  object
#  36  moonrise                      125501 non-null  object
#  37  moonset                       125501 non-null  object
#  38  moon_phase                    125501 non-null  object
#  39  moon_illumination             125501 non-null  int64
#  40  year                          125501 non-null  int32
#  41  month                         125501 non-null  int32
# dtypes: float64(24), int32(2), int64(7), object(9)
# memory usage: 40.2+ MB

# %%
missing_values = df.isnull().sum()

# %%
# Filling numerical missing values with column mean
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Filling categorical missing values with 'Unknown'
categorical_cols = df.select_dtypes(include=["object"]).columns
df[categorical_cols] = df[categorical_cols].fillna("Unknown")

# Verifying missing values again
df.isnull().sum()
# Out:
# timezone                        125501
# country                              0
# location_name                        0
# latitude                             0
# longitude                            0
# last_updated_epoch                   0
# temperature_celsius                  0
# temperature_fahrenheit               0
# condition_text                       0
# wind_mph                             0
# wind_kph                             0
# wind_degree                          0
# wind_direction                       0
# pressure_mb                          0
# pressure_in                          0
# precip_mm                            0
# precip_in                            0
# humidity                             0
# cloud                                0
# feels_like_celsius                   0
# feels_like_fahrenheit                0
# visibility_km                        0
# visibility_miles                     0
# uv_index                             0
# gust_mph                             0
# gust_kph                             0
# air_quality_Carbon_Monoxide          0
# air_quality_Ozone                    0
# air_quality_Nitrogen_dioxide         0
# air_quality_Sulphur_dioxide          0
# air_quality_PM2.5                    0
# air_quality_PM10                     0
# air_quality_us-epa-index             0
# air_quality_gb-defra-index           0
# sunrise                              0
# sunset                               0
# moonrise                             0
# moonset                              0
# moon_phase                           0
# moon_illumination                    0
# year                                 0
# month                                0
# dtype: int64

# %%
# Converting timestamp column to datetime
df["last_updated"] = pd.to_datetime(df["last_updated"], errors="coerce")

# Setting datetime column as index
df.set_index("last_updated", inplace=True)

# Extracted year and month for aggregation
df["year"] = df.index.year
df["month"] = df.index.month
df.head()
# Out:
#                      timezone      country     location_name  latitude  \
# last_updated
# 2024-05-16 13:15:00       NaN  Afghanistan             Kabul     34.52
# 2024-05-16 10:45:00       NaN      Albania            Tirana     41.33
# 2024-05-16 09:45:00       NaN      Algeria           Algiers     36.76
# 2024-05-16 10:45:00       NaN      Andorra  Andorra La Vella     42.50
# 2024-05-16 09:45:00       NaN       Angola            Luanda     -8.84
#
#                      longitude  last_updated_epoch  temperature_celsius  \
# last_updated
# 2024-05-16 13:15:00      69.18          1715849100                 26.6
# 2024-05-16 10:45:00      19.82          1715849100                 19.0
# 2024-05-16 09:45:00       3.05          1715849100                 23.0
# 2024-05-16 10:45:00       1.52          1715849100                  6.3
# 2024-05-16 09:45:00      13.23          1715849100                 26.0
#
#                      temperature_fahrenheit condition_text  wind_mph  ...  \
# last_updated                                                          ...
# 2024-05-16 13:15:00                    79.8  Partly Cloudy       8.3  ...
# 2024-05-16 10:45:00                    66.2  Partly cloudy       6.9  ...
# 2024-05-16 09:45:00                    73.4          Sunny       9.4  ...
# 2024-05-16 10:45:00                    43.3  Light drizzle       7.4  ...
# 2024-05-16 09:45:00                    78.8  Partly cloudy       8.1  ...
#
#                      air_quality_us-epa-index  air_quality_gb-defra-index  \
# last_updated
# 2024-05-16 13:15:00                         1                           1
# 2024-05-16 10:45:00                         1                           1
# 2024-05-16 09:45:00                         1                           1
# 2024-05-16 10:45:00                         1                           1
# 2024-05-16 09:45:00                         5                          10
#
#                       sunrise    sunset  moonrise   moonset      moon_phase  \
# last_updated
# 2024-05-16 13:15:00  04:50 AM  06:50 PM  12:12 PM  01:11 AM  Waxing Gibbous
# 2024-05-16 10:45:00  05:21 AM  07:54 PM  12:58 PM  02:14 AM  Waxing Gibbous
# 2024-05-16 09:45:00  05:40 AM  07:50 PM  01:15 PM  02:14 AM  Waxing Gibbous
# 2024-05-16 10:45:00  06:31 AM  09:11 PM  02:12 PM  03:31 AM  Waxing Gibbous
# 2024-05-16 09:45:00  06:12 AM  05:55 PM  01:17 PM  12:38 AM  Waxing Gibbous
#
#                      moon_illumination  year  month
# last_updated
# 2024-05-16 13:15:00                 55  2024      5
# 2024-05-16 10:45:00                 55  2024      5
# 2024-05-16 09:45:00                 55  2024      5
# 2024-05-16 10:45:00                 55  2024      5
# 2024-05-16 09:45:00                 55  2024      5
#
# [5 rows x 42 columns]

# %%
df.describe()
# Out:
#        timezone       latitude      longitude  last_updated_epoch  \
# count       0.0  125501.000000  125501.000000        1.255010e+05
# mean        NaN      19.194285      21.992818        1.743775e+09
# std         NaN      24.425011      65.793975        1.611019e+07
# min         NaN     -41.300000    -175.200000        1.715849e+09
# 25%         NaN       3.750000      -6.836100        1.729848e+09
# 50%         NaN      17.250000      23.240000        1.743758e+09
# 75%         NaN      40.400000      50.580000        1.757750e+09
# max         NaN      64.150000     179.220000        1.771656e+09
#
#        temperature_celsius  temperature_fahrenheit       wind_mph  \
# count        125501.000000           125501.000000  125501.000000
# mean             21.573732               70.834471       8.066009
# std               9.611703               17.300940       7.360164
# min             -29.800000              -21.600000       2.200000
# 25%              16.300000               61.300000       3.800000
# 50%              24.100000               75.400000       6.900000
# 75%              28.100000               82.600000      11.000000
# max              49.200000              120.600000    1841.200000
#
#             wind_kph    wind_degree    pressure_mb  ...  air_quality_Ozone  \
# count  125501.000000  125501.000000  125501.000000  ...      125501.000000
# mean       12.984579     169.175887    1014.055266  ...          58.863922
# std        11.841975     103.466509      10.595466  ...          31.103468
# min         3.600000       1.000000     947.000000  ...           0.000000
# 25%         6.100000      80.000000    1010.000000  ...          39.000000
# 50%        11.200000     162.000000    1014.000000  ...          56.000000
# 75%        17.600000     256.000000    1018.000000  ...          75.000000
# max      2963.200000     360.000000    3006.000000  ...         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                 125501.000000                125501.000000
# mean                      15.239036                    10.659911
# std                       24.238412                    36.875595
# min                        0.000000                 -9999.000000
# 25%                        1.665000                     1.050000
# 50%                        5.500000                     2.450000
# 75%                       17.760000                     8.550000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count      125501.000000     125501.000000             125501.000000
# mean           24.573293         49.170688                  1.709309
# std            37.781243        151.632697                  0.950215
# min             0.168000      -1848.150000                  1.000000
# 25%             7.100000         10.026000                  1.000000
# 50%            14.245000         20.250000                  1.000000
# 75%            28.120000         42.180000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination           year  \
# count               125501.000000      125501.000000  125501.000000
# mean                     2.632417          49.347671    2024.724807
# std                      2.471696          35.105818       0.598116
# min                      1.000000           0.000000    2024.000000
# 25%                      1.000000          14.000000    2024.000000
# 50%                      2.000000          49.000000    2025.000000
# 75%                      3.000000          84.000000    2025.000000
# max                     10.000000         100.000000    2026.000000
#
#                month
# count  125501.000000
# mean        6.904160
# std         3.478667
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        12.000000
#
# [8 rows x 33 columns]

# %%
# cleaned dataset is saved 
processed_path =  "C:\\Users\\keert\\OneDrive\\Desktop\\ClimateScope\\data\\processed\\weather_cleaned.csv"

df.to_csv(processed_path, index=False)

print("Cleaned dataset saved to:", processed_path)
# Out:
# Cleaned dataset saved to: C:\Users\keert\OneDrive\Desktop\ClimateScope\data\processed\weather_cleaned.csv

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style("whitegrid")

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["temperature_celsius"], bins=40, kde=True)
plt.title("Distribution of Temperature (°C)")
plt.xlabel("Temperature (°C)")
plt.ylabel("Frequency")
plt.show()

# %%
monthly_temp = (
    df.groupby(["year", "month"])["temperature_celsius"]
    .mean()
    .reset_index()
)

plt.figure(figsize=(8,4))
sns.lineplot(
    data=monthly_temp,
    x="month",
    y="temperature_celsius",
    ci=None
)
plt.title("Average Monthly Temperature Trend")
plt.xlabel("Month")
plt.ylabel("Average Temperature (°C)")
plt.show()
# Out:
# C:\Users\keert\AppData\Local\Temp\ipykernel_22492\3835162219.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(

# %%
plt.figure(figsize=(6,4))
sns.histplot(df["precip_mm"], bins=40)
plt.title("Precipitation Distribution (mm)")
plt.xlabel("Precipitation (mm)")
plt.ylabel("Frequency")
plt.show()
